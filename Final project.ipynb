# %%
import requests
import json
import numpy as np
from tqdm.auto import tqdm
from collections import defaultdict
import pandas as pd
import nltk
import pymorphy2
from nltk.corpus import stopwords
import re
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import tree
from sklearn.metrics import mean_absolute_error as MAE

# %% [markdown]
# ## Запрос вакансий с hh.ru

# %% [markdown]
# #### Выбор регионов (города-миллионники России)

# %%
cities = ['Москва', 'Санкт-Петербург', 'Новосибирск', 'Екатеринбург', 'Казань', 'Нижний Новгород', 'Челябинск', 
          'Красноярск', 'Самара', 'Уфа', 'Ростов-на-Дону', 'Омск', 'Краснодар', 'Воронеж', 'Пермь', 'Волгоград']
regions = []
for city in cities:
    url = f'https://api.hh.ru/suggests/area_leaves?text={city}'
    res = requests.get(url)
    for item in res.json()['items']:
        if item['text'] in cities:
            regions.append(item)

# %%
regions
# Out:
# [{'id': '1', 'text': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#  {'id': '2', 'text': 'Санкт-Петербург', 'url': 'https://api.hh.ru/areas/2'},
#  {'id': '4', 'text': 'Новосибирск', 'url': 'https://api.hh.ru/areas/4'},
#  {'id': '3', 'text': 'Екатеринбург', 'url': 'https://api.hh.ru/areas/3'},
#  {'id': '88', 'text': 'Казань', 'url': 'https://api.hh.ru/areas/88'},
#  {'id': '66', 'text': 'Нижний Новгород', 'url': 'https://api.hh.ru/areas/66'},
#  {'id': '104', 'text': 'Челябинск', 'url': 'https://api.hh.ru/areas/104'},
#  {'id': '54', 'text': 'Красноярск', 'url': 'https://api.hh.ru/areas/54'},
#  {'id': '78', 'text': 'Самара', 'url': 'https://api.hh.ru/areas/78'},
#  {'id': '99', 'text': 'Уфа', 'url': 'https://api.hh.ru/areas/99'},
#  {'id': '76', 'text': 'Ростов-на-Дону', 'url': 'https://api.hh.ru/areas/76'},
#  {'id': '68', 'text': 'Омск', 'url': 'https://api.hh.ru/areas/68'},
#  {'id': '53', 'text': 'Краснодар', 'url': 'https://api.hh.ru/areas/53'},
#  {'id': '26', 'text': 'Воронеж', 'url': 'https://api.hh.ru/areas/26'},
#  {'id': '72', 'text': 'Пермь', 'url': 'https://api.hh.ru/areas/72'},
#  {'id': '24', 'text': 'Волгоград', 'url': 'https://api.hh.ru/areas/24'}]

# %% [markdown]
# #### Запрос списка вакансий по каждому региону

# %%
all_regions_vacs=[]
for region in tqdm(range(len(regions))):
    reg_id = regions[region]['id']
    for i in range(20):
        url = f'https://api.hh.ru/vacancies?page={i}&per_page=100&area={reg_id}&text=data'
        res = requests.get(url)
        vacancies = res.json()
        all_regions_vacs.extend(vacancies.get('items'))
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]

# %%
len(all_regions_vacs)
# Out:
# 3322

# %% [markdown]
# #### Очистка параметров, которые не требуются для анализа

# %%
for vac in tqdm(range(len(all_regions_vacs))):
    for key in list(all_regions_vacs[vac].keys()):
        if 'url' in key:
            all_regions_vacs[vac].pop(key)
        if key=='address':
            all_regions_vacs[vac].pop(key)
        if key=='insider_interview':
            all_regions_vacs[vac].pop(key)            
    all_regions_vacs[vac]['area']=all_regions_vacs[vac]['area']['name']
    all_regions_vacs[vac]['employer']=all_regions_vacs[vac]['employer']['name']
    all_regions_vacs[vac]['type']=all_regions_vacs[vac]['type']['name']
    all_regions_vacs[vac]['schedule']=all_regions_vacs[vac]['schedule']['name']
# Out:
#   0%|          | 0/3322 [00:00<?, ?it/s]

# %%
all_regions_vacs[0]
# Out:
# {'id': '71426958',
#  'premium': True,
#  'name': 'Data Scientist (команда Поиска)',
#  'department': {'id': 'hh-1455-ds',
#   'name': 'HeadHunter::Analytics/Data Science'},
#  'has_test': False,
#  'response_letter_required': True,
#  'area': 'Москва',
#  'salary': {'from': 350000, 'to': None, 'currency': 'RUR', 'gross': True},
#  'type': 'Открытая',
#  'sort_point_distance': None,
#  'published_at': '2022-10-27T15:35:01+0300',
#  'created_at': '2022-10-27T15:35:01+0300',
#  'archived': False,
#  'relations': [],
#  'employer': 'HeadHunter',
#  'snippet': {'requirement': 'Опыт реализации и применения моделей машинного обучения в продакшн. Понимание основных методов и алгоритмов Machine Learning. Знание принципов работы нейросетевых...',
#   'responsibility': 'Развитие моделей поискового ранжирования и рекомендательных систем. Тюнинг существующих моделей, feature engineering, а также построение новых решений с нуля. '},
#  'contacts': None,
#  'schedule': 'Полный день',
#  'working_days': [],
#  'working_time_intervals': [],
#  'working_time_modes': [],
#  'accept_temporary': False}

# %%
vacancies_table = pd.json_normalize(all_regions_vacs)
vacancies_table["published_at"]=pd.to_datetime(vacancies_table["published_at"])
vacancies_table["created_at"]=pd.to_datetime(vacancies_table["created_at"])
vacancies_table.dropna(how='all', axis=1, inplace=True)
vacancies_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3322 entries, 0 to 3321
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        3322 non-null   object
#  1   premium                   3322 non-null   bool
#  2   name                      3322 non-null   object
#  3   has_test                  3322 non-null   bool
#  4   response_letter_required  3322 non-null   bool
#  5   area                      3322 non-null   object
#  6   type                      3322 non-null   object
#  7   published_at              3322 non-null   datetime64[ns, pytz.FixedOffset(180)]
#  8   created_at                3322 non-null   datetime64[ns, pytz.FixedOffset(180)]
#  9   archived                  3322 non-null   bool
#  10  relations                 3322 non-null   object
#  11  employer                  3322 non-null   object
#  12  schedule                  3322 non-null   object
#  13  working_days              3322 non-null   object
#  14  working_time_intervals    3322 non-null   object
#  15  working_time_modes        3322 non-null   object
#  16  accept_temporary          3322 non-null   bool
#  17  department.id             812 non-null    object
#  18  department.name           812 non-null    object
#  19  salary.from               681 non-null    float64
#  20  salary.to                 398 non-null    float64
#  21  salary.currency           782 non-null    object
#  22  salary.gross              781 non-null    object
#  23  snippet.requirement       3239 non-null   object
#  24  snippet.responsibility    3292 non-null   object
# dtypes: bool(5), datetime64[ns, pytz.FixedOffset(180)](2), float64(2), object(16)
# memory usage: 535.4+ KB

# %%
vacancies_table.head()
# Out:
#          id  premium                                           name  has_test  \
# 0  71426958     True                Data Scientist (команда Поиска)     False
# 1  70994665    False  ML Team Lead (Играющий тренер data scientist)     False
# 2  71703435    False                       Chief Data Officer (CDO)     False
# 3  70735115    False            Senior Data Scientist / ML Engineer     False
# 4  71559745    False                Data scientist / ML разработчик     False
#
#    response_letter_required    area      type              published_at  \
# 0                      True  Москва  Открытая 2022-10-27 15:35:01+03:00
# 1                     False  Москва  Открытая 2022-10-28 19:33:00+03:00
# 2                     False  Москва  Открытая 2022-10-28 13:56:31+03:00
# 3                     False  Москва  Открытая 2022-10-28 10:27:43+03:00
# 4                     False  Москва  Открытая 2022-10-28 13:03:53+03:00
#
#                  created_at  archived  ... working_time_modes  \
# 0 2022-10-27 15:35:01+03:00     False  ...                 []
# 1 2022-10-28 19:33:00+03:00     False  ...                 []
# 2 2022-10-28 13:56:31+03:00     False  ...                 []
# 3 2022-10-28 10:27:43+03:00     False  ...                 []
# 4 2022-10-28 13:03:53+03:00     False  ...                 []
#
#   accept_temporary department.id                     department.name  \
# 0            False    hh-1455-ds  HeadHunter::Analytics/Data Science
# 1            False           NaN                                 NaN
# 2            False           NaN                                 NaN
# 3            False           NaN                                 NaN
# 4            False           NaN                                 NaN
#
#   salary.from salary.to  salary.currency salary.gross  \
# 0    350000.0       NaN              RUR         True
# 1    750000.0       NaN              RUR        False
# 2      3000.0    3700.0              EUR         True
# 3    300000.0  450000.0              RUR        False
# 4    120000.0  220000.0              RUR        False
#
#                                  snippet.requirement  \
# 0  Опыт реализации и применения моделей машинного...
# 1  Глубокие знания в области Deep Learning/ Machi...
# 2  The successful candidate must have a proven tr...
# 3  DS-stack: docker, python 3.7, sql, pandas, sci...
# 4  Высшее образование в области прикладной матема...
#
#                               snippet.responsibility
# 0  Развитие моделей поискового ранжирования и рек...
# 1  Основной проект компании - разработка унифицир...
# 2  ...and protecting <highlighttext>data</highlig...
# 3  Детали. Нейронки, контент-бейзд рекомендации, ...
# 4  Участие в поддержке текущих, а также развертыв...
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Определение уровня вакансии по описанию

# %%
def vac_level(row):
    if 'Junior' in row['name']:
        return 'Junior'
    if 'Middle' in row['name']:
        return 'Middle'
    if ('Senior' in row['name'])|('Старший' in row['name']):
        return 'Senior'
    if ('Chief' in row['name'])|('Head' in row['name'])|('Lead' in row['name'])|('Руководитель' in row['name']):
        return 'Lead'

# %%
vacancies_table['name'].value_counts()
# Out:
# Data Engineer                                        68
# Data Scientist                                       44
# Data Analyst                                         27
# Data engineer                                        25
# Java-разработчик                                     25
#                                                      ..
# Frontend-разработчик (образовательная платформа)      1
# HR Officer (British Embassy in Moscow, RUS22.474)     1
# Dev-ops engineer                                      1
# Middle Golang developer                               1
# Frontend-разработчик Vue                              1
# Name: name, Length: 2383, dtype: int64

# %%
vacancies_table['Level'] = vacancies_table.apply(lambda row: vac_level(row), axis=1)
vacancies_table
# Out:
#             id  premium                                               name  \
# 0     71426958     True                    Data Scientist (команда Поиска)
# 1     70994665    False      ML Team Lead (Играющий тренер data scientist)
# 2     71703435    False                           Chief Data Officer (CDO)
# 3     70735115    False                Senior Data Scientist / ML Engineer
# 4     71559745    False                    Data scientist / ML разработчик
# ...        ...      ...                                                ...
# 3317  71415345    False                                      ETL-developer
# 3318  71145212    False  Тайный покупатель (оператор проверки объявлени...
# 3319  71119665    False                           Frontend-разработчик Vue
# 3320  69015080    False                     Менеджер по работе с клиентами
# 3321  70798709    False                    Java Developer (Middle+/Senior)
#
#       has_test  response_letter_required       area      type  \
# 0        False                      True     Москва  Открытая
# 1        False                     False     Москва  Открытая
# 2        False                     False     Москва  Открытая
# 3        False                     False     Москва  Открытая
# 4        False                     False     Москва  Открытая
# ...        ...                       ...        ...       ...
# 3317     False                     False  Волгоград  Открытая
# 3318     False                     False  Волгоград  Открытая
# 3319      True                     False  Волгоград  Открытая
# 3320     False                     False  Волгоград  Открытая
# 3321     False                     False  Волгоград  Открытая
#
#                   published_at                created_at  archived  ...  \
# 0    2022-10-27 15:35:01+03:00 2022-10-27 15:35:01+03:00     False  ...
# 1    2022-10-28 19:33:00+03:00 2022-10-28 19:33:00+03:00     False  ...
# 2    2022-10-28 13:56:31+03:00 2022-10-28 13:56:31+03:00     False  ...
# 3    2022-10-28 10:27:43+03:00 2022-10-28 10:27:43+03:00     False  ...
# 4    2022-10-28 13:03:53+03:00 2022-10-28 13:03:53+03:00     False  ...
# ...                        ...                       ...       ...  ...
# 3317 2022-10-21 10:20:15+03:00 2022-10-21 10:20:15+03:00     False  ...
# 3318 2022-10-14 13:09:02+03:00 2022-10-14 13:09:02+03:00     False  ...
# 3319 2022-10-13 18:05:51+03:00 2022-10-13 18:05:51+03:00     False  ...
# 3320 2022-10-12 15:17:42+03:00 2022-10-12 15:17:42+03:00     False  ...
# 3321 2022-10-05 11:34:12+03:00 2022-10-05 11:34:12+03:00     False  ...
#
#      accept_temporary department.id                     department.name  \
# 0               False    hh-1455-ds  HeadHunter::Analytics/Data Science
# 1               False           NaN                                 NaN
# 2               False           NaN                                 NaN
# 3               False           NaN                                 NaN
# 4               False           NaN                                 NaN
# ...               ...           ...                                 ...
# 3317            False           NaN                                 NaN
# 3318             True           NaN                                 NaN
# 3319            False           NaN                                 NaN
# 3320            False           NaN                                 NaN
# 3321            False           NaN                                 NaN
#
#      salary.from salary.to salary.currency  salary.gross  \
# 0       350000.0       NaN             RUR          True
# 1       750000.0       NaN             RUR         False
# 2         3000.0    3700.0             EUR          True
# 3       300000.0  450000.0             RUR         False
# 4       120000.0  220000.0             RUR         False
# ...          ...       ...             ...           ...
# 3317         NaN       NaN             NaN           NaN
# 3318         NaN   22500.0             RUR         False
# 3319     90000.0  160000.0             RUR         False
# 3320     45000.0       NaN             RUR          True
# 3321         NaN       NaN             NaN           NaN
#
#                                     snippet.requirement  \
# 0     Опыт реализации и применения моделей машинного...
# 1     Глубокие знания в области Deep Learning/ Machi...
# 2     The successful candidate must have a proven tr...
# 3     DS-stack: docker, python 3.7, sql, pandas, sci...
# 4     Высшее образование в области прикладной матема...
# ...                                                 ...
# 3317  Опыт работы с NoSQL (сlickhouse, cassandra, el...
# 3318  Готовы открыть самозанятость и работать по дог...
# 3319  Ищем фронтменов для текущих и новых проектов. ...
# 3320  Мы обучим всему, что необходимо. Единственное,...
# 3321  Опыт разработки на Java от 3-х лет. Опыт разра...
#
#                                  snippet.responsibility   Level
# 0     Развитие моделей поискового ранжирования и рек...    None
# 1     Основной проект компании - разработка унифицир...    Lead
# 2     ...and protecting <highlighttext>data</highlig...    Lead
# 3     Детали. Нейронки, контент-бейзд рекомендации, ...  Senior
# 4     Участие в поддержке текущих, а также развертыв...    None
# ...                                                 ...     ...
# 3317  Изучать возможности разных ETL-систем и приним...    None
# 3318  Обзвон объявлений по недвижимости в качестве т...    None
# 3319                                               None    None
# 3320  Вести телефонные переговоры с клиентами с цель...    None
# 3321  Инвестиции. Строим уникальный и технологичный ...  Middle
#
# [3322 rows x 26 columns]

# %%
vacancies_table['Level'].value_counts()
# Out:
# Senior    421
# Lead      278
# Middle    157
# Junior     54
# Name: Level, dtype: int64

# %% [markdown]
# #### Добавляем ключевые навыки

# %%
#Скачиваем описания всех вакансий
all_skills = []
descriptions = []
all_id = list(vacancies_table['id'])
for i in tqdm(range(len(all_id))):
    url = f'https://api.hh.ru/vacancies/{all_id[i]}'
    res = requests.get(url)
    all_skills.append(res.json().get('key_skills'))
    descriptions.append(res.json().get('description'))
# Out:
#   0%|          | 0/3322 [00:00<?, ?it/s]

# %%
url = f'https://api.hh.ru/vacancies/71426958'
res = requests.get(url)
res.json()
# Out:
# {'id': '71426958',
#  'premium': True,
#  'billing_type': {'id': 'premium', 'name': 'Премиум'},
#  'relations': [],
#  'name': 'Data Scientist (команда Поиска)',
#  'insider_interview': None,
#  'response_letter_required': True,
#  'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#  'salary': {'from': 350000, 'to': None, 'currency': 'RUR', 'gross': True},
#  'type': {'id': 'open', 'name': 'Открытая'},
#  'address': {'city': 'Москва',
#   'street': 'улица Годовикова',
#   'building': '9с10',
#   'description': None,
#   'lat': 55.809343,
#   'lng': 37.628505,
#   'raw': 'Москва, улица Годовикова, 9с10',
#   'metro': {'station_name': 'Алексеевская',
#    'line_name': 'Калужско-Рижская',
#    'station_id': '6.8',
#    'line_id': '6',
#    'lat': 55.807794,
#    'lng': 37.638699},
#   'metro_stations': [{'station_name': 'Алексеевская',
#     'line_name': 'Калужско-Рижская',
#     'station_id': '6.8',
#     'line_id': '6',
#     'lat': 55.807794,
#     'lng': 37.638699}]},
#  'allow_messages': True,
#  'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#  'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#  'employment': {'id': 'full', 'name': 'Полная занятость'},
#  'department': {'id': 'hh-1455-ds',
#   'name': 'HeadHunter::Analytics/Data Science'},
#  'contacts': None,
#  'description': '<p>Мы ищем data scientist’а с опытом работы в текстовых задачах, рекомендательных или поисковых системах. Если вы хорошо знаете математику, любите копаться в больших массивах данных, находить в них закономерности, и умеете внедрять свои решения в продакшн, то мы будем рады видеть вас в нашей компании.</p> <p>Мы развиваем ML-модели ранжирования поиска и рекомендаций, которые позволяют находить работу людям со всей страны. Наша основная задача состоит в количественном росте продуктовых метрик, таких как кол-во откликов/приглашений, все гипотезы строго проверяются с помощью A/B-экспериментов. Наши решения работают в online режиме под большой нагрузкой на поисковом кластере из 100+ машин. Мы работаем в продуктовых кросс-функциональных (frontend/backend/data science) командах по гибким методологиям. </p> <p><strong>Требования</strong></p> <ul> <li> <p>Опыт реализации и применения моделей машинного обучения в продакшн;</p> </li> <li> <p>Понимание основных методов и алгоритмов Machine Learning;</p> </li> <li> <p>Знание принципов работы нейросетевых моделей для обработки текста;</p> </li> <li> <p>Опыт в ранжировании, рекомендациях, а также в nlp-задачах будет большим плюсом;</p> </li> <li> <p>Уверенное владение Python (numpy, scipy, pytorch, sklearn), приветствуется знание и опыт с Java;</p> </li> <li> <p>Алгоритмическая подготовка: знание основных алгоритмов и структур данных;</p> </li> <li> <p>Желателен опыт работы с различными источниками данных: SQL, Cassandra, Hive, Presto, Kafka, etc.;</p> </li> <li> <p>Понимание и опыт работы с A/B-экспериментами;</p> </li> </ul> <p><strong>Обязанности</strong></p> <ul> <li> <p>Развитие моделей поискового ранжирования и рекомендательных систем;</p> </li> <li> <p>Тюнинг существующих моделей, feature engineering, а также построение новых решений с нуля;</p> </li> <li> <p>Прототипирование и доведение своих решений до продакшна на python;</p> </li> <li> <p>Полная поддержка своих моделей: от написания запроса для выгрузки обучающей выборки из хранилищ данных до анализа результатов A/B-экспериментов и переключения всех пользователей на новый функционал;</p> </li> </ul> <p><strong>Условия</strong></p> <ul> <li> <p>Возможность выбора места работы: удаленно или из офиса;</p> </li> <li> <p>Гибкий график рабочего дня;</p> </li> <li> <p>Оформление в соответствии с ТК РФ, «Белая» заработная плата, выплачиваемая точно в срок;</p> </li> <li> <p>Корпоративное ДМС после завершения испытательного срока (решаем вопросы со здоровьем быстро и удобно);</p> </li> <li> <p>Возможность профессионального развития, обучение за счет компании, участие в специализированных конференциях;</p> </li> </ul>',
#  'branded_description': '\n<style type="text/css">\n .tmplt_hh {\n     width: 100%;\n     margin: 10px auto;\n     overflow: hidden;\n     font-family: \'Arial\', sans-serif;\n }\n \n .tmplt_hh-clearfix:before,\n .tmplt_hh-clearfix:after {\n     content: "";\n     display: table;\n }\n \n .tmplt_hh-clearfix:after {\n     clear: both;\n }\n \n .tmplt_hh h1,\n .tmplt_hh h2,\n .tmplt_hh h3,\n .tmplt_hh h4,\n .tmplt_hh h5,\n .tmplt_hh h6,\n .tmplt_hh p,\n .tmplt_hh blockquote,\n .tmplt_hh pre,\n .tmplt_hh a,\n .tmplt_hh abbr,\n .tmplt_hh acronym,\n .tmplt_hh address,\n .tmplt_hh big,\n .tmplt_hh cite,\n .tmplt_hh code,\n .tmplt_hh img,\n .tmplt_hh ol,\n .tmplt_hh ul,\n .tmplt_hh li,\n .tmplt_hh footer,\n .tmplt_hh header {\n     margin: 0;\n     padding: 0;\n     border: 0;\n     font-size: 100%;\n     font: inherit;\n     vertical-align: baseline;\n }\n \n .tmplt_hh ul,\n .tmplt_hh ul ul {\n     list-style: none;\n }\n \n .tmplt_hh-content ol li b,\n .tmplt_hh-content ol li strong,\n .tmplt_hh-content ol li p b,\n .tmplt_hh-content ol li p strong,\n .tmplt_hh-content ul li b,\n .tmplt_hh-content ul li strong,\n .tmplt_hh-content ul li p b,\n .tmplt_hh-content ul li p strong {\n     font-weight: normal;\n     font-size: inherit!important;\n     line-height: inherit!important;\n     color: inherit!important;\n     margin: 0!important;\n     padding: 0!important;\n     background: none!important;\n     display: inline!important;\n     text-transform: none;\n }\n \n .tmplt_hh-content ol li p,\n .tmplt_hh-content ul li p {\n     font-weight: normal;\n     margin: 0;\n }\n \n .tmplt_hh-content p b,\n .tmplt_hh-content p strong {\n     display: inline;\n     margin: 0;\n }\n \n .tmplt_hh_flex {\n     display: -webkit-box;\n     display: -moz-box;\n     display: -ms-flexbox;\n     display: -webkit-flex;\n     display: flex;\n     -ms-flex-wrap: wrap;\n     flex-wrap: wrap;\n     -ms-flex-pack: justify;\n     justify-content: space-between;\n }\n /* Styles slider */\n \n .tmplt_hh-swiper-container {\n     margin-left: auto;\n     margin-right: auto;\n     position: relative;\n     overflow: hidden;\n     /* Fix of Webkit flickering */\n     z-index: 1;\n }\n \n .swiper-container-no-flexbox .swiper-slide {\n     float: left;\n }\n \n .swiper-container-vertical > .swiper-wrapper {\n     -webkit-box-orient: vertical;\n     -moz-box-orient: vertical;\n     -ms-flex-direction: column;\n     -webkit-flex-direction: column;\n     flex-direction: column;\n }\n \n .tmplt_hh-swiper-container .swiper-wrapper {\n     position: relative;\n     width: 100%;\n     z-index: 1;\n     display: -webkit-box;\n     display: -moz-box;\n     display: -ms-flexbox;\n     display: -webkit-flex;\n     display: flex;\n     -webkit-transition-property: -webkit-transform;\n     -moz-transition-property: -moz-transform;\n     -o-transition-property: -o-transform;\n     -ms-transition-property: -ms-transform;\n     transition-property: transform;\n     -webkit-box-sizing: content-box;\n     -moz-box-sizing: content-box;\n     box-sizing: content-box;\n }\n \n .swiper-container-android .swiper-slide,\n .swiper-wrapper {\n     -webkit-transform: translate3d(0px, 0, 0);\n     -moz-transform: translate3d(0px, 0, 0);\n     -o-transform: translate(0px, 0px);\n     -ms-transform: translate3d(0px, 0, 0);\n     transform: translate3d(0px, 0, 0);\n }\n \n .swiper-container-multirow > .swiper-wrapper {\n     -webkit-box-lines: multiple;\n     -moz-box-lines: multiple;\n     -ms-flex-wrap: wrap;\n     -webkit-flex-wrap: wrap;\n     flex-wrap: wrap;\n }\n \n .swiper-container-free-mode > .swiper-wrapper {\n     -webkit-transition-timing-function: ease-out;\n     -moz-transition-timing-function: ease-out;\n     -ms-transition-timing-function: ease-out;\n     -o-transition-timing-function: ease-out;\n     transition-timing-function: ease-out;\n     margin: 0 auto;\n }\n \n .tmplt_hh-swiper-container .swiper-slide {\n     -webkit-flex-shrink: 0;\n     -ms-flex: 0 0 auto;\n     flex-shr ...
#  'vacancy_constructor_template': None,
#  'key_skills': [{'name': 'Python'},
#   {'name': 'PyTorch'},
#   {'name': 'SQL'},
#   {'name': 'Machine Learning'},
#   {'name': 'Анализ данных'},
#   {'name': 'data science'},
#   {'name': 'numpy'},
#   {'name': 'scipy'},
#   {'name': 'pandas'},
#   {'name': 'lightgbm'},
#   {'name': 'pytorch'},
#   {'name': 'scikit-learn'},
#   {'name': 'neural nets'},
#   {'name': 'nlp'},
#   {'name': 'search ranking'},
#   {'name': 'recommender systems'},
#   {'name': 'a/b-experiments'},
#   {'name': 'hadoop'},
#   {'name': 'hive'},
#   {'name': 'presto'},
#   {'name': 'Mathematics'}],
#  'accept_handicapped': False,
#  'accept_kids': False,
#  'archived': False,
#  'response_url': None,
#  'specializations': [{'id': '17.751',
#    'name': 'Другое',
#    'profarea_id': '17',
#    'profarea_name': 'Продажи'},
#   {'id': '1.25',
#    'name': 'Аналитик',
#    'profarea_id': '1',
#    'profarea_name': 'Информационные технологии, интернет, телеком'},
#   {'id': '3.26',
#    'name': 'Аналитик',
#    'profarea_id': '3',
#    'profarea_name': 'Маркетинг, реклама, PR'},
#   {'id': '12.746',
#    'name': 'Другое',
#    'profarea_id': '12',
#    'profarea_name': 'Консультирование'}],
#  'professional_roles': [{'id': '10', 'name': 'Аналитик'}],
#  'code': None,
#  'hidden': False,
#  'quick_responses_allowed': False,
#  'driver_license_types': [],
#  'accept_incomplete_resumes': False,
#  'employer': {'id': '1455',
#   'name': 'HeadHunter',
#   'url': 'https://api.hh.ru/employers/1455',
#   'alternate_url': 'https://hh.ru/employer/1455',
#   'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/907140.png',
#    '240': 'https://hhcdn.ru/employer-logo/4069248.png',
#    '90': 'https://hhcdn.ru/employer-logo/4069247.png'},
#   'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1455',
#   'trusted': True},
#  'published_at': '2022-10-27T15:35:01+0300',
#  'created_at': '2022-10-27T15:35:01+0300',
#  'initial_created_at': '2022-10-21T13:54:51+0300',
#  'negotiations_url': None,
#  'suitable_resumes_url': None,
#  'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=71426958',
#  'has_test': False,
#  'test': None,
#  'alternate_url': 'https://hh.ru/vacancy/71426958',
#  'working_days': [],
#  'working_time_intervals': [],
#  'working_time_modes': [],
#  'accept_temporary': False,
#  'languages': []}

# %%
skill_list = []
for skill in all_skills:
    if skill:
        temp_arr = []
        for item in skill:
            temp_arr.append(item["name"])
        skill_list.append(temp_arr)
    else: skill_list.append(False)

# %%
#Собираем навыки в объект Series, чтобы добавить колонкой к датафрейму
skills_table=pd.Series(skill_list)
skills_table.head(3)
# Out:
# 0    [Python, PyTorch, SQL, Machine Learning, Анали...
# 1    [Python, PyTorch, Tensorflow, Deep Learning, K...
# 2    [Python, SQL, Английский язык, Leadership Skil...
# dtype: object

# %%
#Добавляем колонку к датафрейму
vacs_and_skills=vacancies_table.copy(deep = True)
vacs_and_skills.insert(column="skills", value = skills_table,loc = 3)
vacs_and_skills.insert(column="description", value = pd.Series(descriptions),loc = 4)
vacs_and_skills.head()
# Out:
#          id  premium                                           name  \
# 0  71426958     True                Data Scientist (команда Поиска)
# 1  70994665    False  ML Team Lead (Играющий тренер data scientist)
# 2  71703435    False                       Chief Data Officer (CDO)
# 3  70735115    False            Senior Data Scientist / ML Engineer
# 4  71559745    False                Data scientist / ML разработчик
#
#                                               skills  \
# 0  [Python, PyTorch, SQL, Machine Learning, Анали...
# 1  [Python, PyTorch, Tensorflow, Deep Learning, K...
# 2  [Python, SQL, Английский язык, Leadership Skil...
# 3  [Docker, Python, SQL, Pandas, Numpy, Scipy, Sc...
# 4  [Python, SQL, A/B тесты, Airflow, Spark, Flask...
#
#                                          description  has_test  \
# 0  <p>Мы ищем data scientist’а с опытом работы в ...     False
# 1  <p>ООО &quot;Нейросетевая корпорация ЭкоСфера&...     False
# 2  <p>We are an established b2b events organizing...     False
# 3  <p><strong>Mindbox</strong> — крупнейшая в Рос...     False
# 4  <p><strong>Компания Loymax - лидер на рынке IT...     False
#
#    response_letter_required    area      type              published_at  ...  \
# 0                      True  Москва  Открытая 2022-10-27 15:35:01+03:00  ...
# 1                     False  Москва  Открытая 2022-10-28 19:33:00+03:00  ...
# 2                     False  Москва  Открытая 2022-10-28 13:56:31+03:00  ...
# 3                     False  Москва  Открытая 2022-10-28 10:27:43+03:00  ...
# 4                     False  Москва  Открытая 2022-10-28 13:03:53+03:00  ...
#
#   accept_temporary  department.id                     department.name  \
# 0            False     hh-1455-ds  HeadHunter::Analytics/Data Science
# 1            False            NaN                                 NaN
# 2            False            NaN                                 NaN
# 3            False            NaN                                 NaN
# 4            False            NaN                                 NaN
#
#   salary.from salary.to salary.currency salary.gross  \
# 0    350000.0       NaN             RUR         True
# 1    750000.0       NaN             RUR        False
# 2      3000.0    3700.0             EUR         True
# 3    300000.0  450000.0             RUR        False
# 4    120000.0  220000.0             RUR        False
#
#                                  snippet.requirement  \
# 0  Опыт реализации и применения моделей машинного...
# 1  Глубокие знания в области Deep Learning/ Machi...
# 2  The successful candidate must have a proven tr...
# 3  DS-stack: docker, python 3.7, sql, pandas, sci...
# 4  Высшее образование в области прикладной матема...
#
#                               snippet.responsibility   Level
# 0  Развитие моделей поискового ранжирования и рек...    None
# 1  Основной проект компании - разработка унифицир...    Lead
# 2  ...and protecting <highlighttext>data</highlig...    Lead
# 3  Детали. Нейронки, контент-бейзд рекомендации, ...  Senior
# 4  Участие в поддержке текущих, а также развертыв...    None
#
# [5 rows x 28 columns]

# %% [markdown]
# #### Нормализуем текст в описании вакансий, удаляем лишние символы

# %%
def cleaner(text):
    if text == None:
        return 'Empty'
    clean_text = re.sub(re.compile('<.*?>'), '', text)
    clean_text = re.sub(re.compile('\&.*?;'), '', clean_text).lower()
    return clean_text

# %%
vacs_and_skills['description'] = vacs_and_skills['description'].apply(lambda x:cleaner(x))
vacs_and_skills
# Out:
#             id  premium                                               name  \
# 0     71426958     True                    Data Scientist (команда Поиска)
# 1     70994665    False      ML Team Lead (Играющий тренер data scientist)
# 2     71703435    False                           Chief Data Officer (CDO)
# 3     70735115    False                Senior Data Scientist / ML Engineer
# 4     71559745    False                    Data scientist / ML разработчик
# ...        ...      ...                                                ...
# 3317  71415345    False                                      ETL-developer
# 3318  71145212    False  Тайный покупатель (оператор проверки объявлени...
# 3319  71119665    False                           Frontend-разработчик Vue
# 3320  69015080    False                     Менеджер по работе с клиентами
# 3321  70798709    False                    Java Developer (Middle+/Senior)
#
#                                                  skills  \
# 0     [Python, PyTorch, SQL, Machine Learning, Анали...
# 1     [Python, PyTorch, Tensorflow, Deep Learning, K...
# 2     [Python, SQL, Английский язык, Leadership Skil...
# 3     [Docker, Python, SQL, Pandas, Numpy, Scipy, Sc...
# 4     [Python, SQL, A/B тесты, Airflow, Spark, Flask...
# ...                                                 ...
# 3317  [SQL, Python, Java, PostgreSQL, ETL, Clickhous...
# 3318  [Консультирование клиентов по телефону, Коммун...
# 3319  [JavaScript, Vue.js, HTML, CSS, Babel, Webpack...
# 3320  [Телефонные переговоры, Работа с большим объем...
# 3321  [Spring Framework, PostgreSQL, Hibernate ORM, ...
#
#                                             description  has_test  \
# 0     мы ищем data scientist’а с опытом работы в тек...     False
# 1     ооо нейросетевая корпорация экосфера занимаетс...     False
# 2     we are an established b2b events organizing bu...     False
# 3     mindbox — крупнейшая в россии облачная платфор...     False
# 4     компания loymax - лидер на рынке it решений по...     False
# ...                                                 ...       ...
# 3317  ищем коллегу на проект по созданию и развитию ...     False
# 3318  компания training data занимается разметкой да...     False
# 3319  justwork — аутсорс-разработчик систем со сложн...      True
# 3320  idf eurasia специализируется на data science, ...     False
# 3321  сейчас мы расширяем команды и ищем разработчик...     False
#
#       response_letter_required       area      type              published_at  \
# 0                         True     Москва  Открытая 2022-10-27 15:35:01+03:00
# 1                        False     Москва  Открытая 2022-10-28 19:33:00+03:00
# 2                        False     Москва  Открытая 2022-10-28 13:56:31+03:00
# 3                        False     Москва  Открытая 2022-10-28 10:27:43+03:00
# 4                        False     Москва  Открытая 2022-10-28 13:03:53+03:00
# ...                        ...        ...       ...                       ...
# 3317                     False  Волгоград  Открытая 2022-10-21 10:20:15+03:00
# 3318                     False  Волгоград  Открытая 2022-10-14 13:09:02+03:00
# 3319                     False  Волгоград  Открытая 2022-10-13 18:05:51+03:00
# 3320                     False  Волгоград  Открытая 2022-10-12 15:17:42+03:00
# 3321                     False  Волгоград  Открытая 2022-10-05 11:34:12+03:00
#
#       ... accept_temporary  department.id                     department.name  \
# 0     ...            False     hh-1455-ds  HeadHunter::Analytics/Data Science
# 1     ...            False            NaN                                 NaN
# 2     ...            False            NaN                                 NaN
# 3     ...            False            NaN                                 NaN
# 4     ...            False            NaN                                 NaN
# ...   ...              ...            ...                                 ...
# 3317  ...            False            NaN                                 NaN
# 3318  ...             True            NaN                                 NaN
# 3319  ...            False            NaN                                 NaN
# 3320  ...            False            NaN                                 NaN
# 3321  ...            False            NaN                                 NaN
#
#      salary.from salary.to salary.currency salary.gross  \
# 0       350000.0       NaN             RUR         True
# 1       750000.0       NaN             RUR        False
# 2         3000.0    3700.0             EUR         True
# 3       300000.0  450000.0             RUR        False
# 4       120000.0  220000.0             RUR        False
# ...          ...       ...             ...          ...
# 3317         NaN       NaN             NaN          NaN
# 3318         NaN   22500.0             RUR        False
# 3319     90000.0  160000.0             RUR        False
# 3320     45000.0       NaN             RUR         True
# 3321         NaN       NaN             NaN          NaN
#
#                                     snippet.requirement  \
# 0     Опыт реализации и применения моделей машинного...
# 1     Глубокие знания в области Deep Learning/ Machi...
# 2     The successful candidate must have a proven tr...
# 3     DS-stack: docker, python 3.7, sql, pandas, sci...
# 4     Высшее образование в области прикладной матема...
# ...                                                 ...
# 3317  Опыт работы с NoSQL (сlickhouse, cassandra, el...
# 3318  Готовы открыть самозанятость и работать по дог...
# 3319  Ищем фронтменов для текущих и новых проектов. ...
# 3320  Мы обучим всему, что необходимо. Единственное,...
# 3321  Опыт разработки на Java от 3-х лет. Опыт разра...
#
#                                  snippet.responsibility   Level
# 0     Развитие моделей поискового ранжирования и рек...    None
# 1     Основной проект компании - разработка унифицир...    Lead
# 2     ...and protecting <highlighttext>data</highlig...    Lead
# 3     Детали. Нейронки, контент-бейзд рекомендации, ...  Senior
# 4     Участие в поддержке текущих, а также развертыв...    None
# ...                                                 ...     ...
# 3317  Изучать возможности разных ETL-систем и приним...    None
# 3318  Обзвон объявлений по недвижимости в качестве т...    None
# 3319                                               None    None
# 3320  Вести телефонные переговоры с клиентами с цель...    None
# 3321  Инвестиции. Строим уникальный и технологичный ...  Middle
#
# [3322 rows x 28 columns]

# %% [markdown]
# #### Прогнозируем уровень вакансии по ее описанию

# %%
leveled_vacs = vacs_and_skills[vacs_and_skills['Level'].notnull()].copy()
not_leveled_vacs = vacs_and_skills[vacs_and_skills['Level'].isnull()].copy()
leveled_vacs['Level'].unique()
# Out:
# array(['Lead', 'Senior', 'Junior', 'Middle'], dtype=object)

# %%
nltk.download('stopwords')
stop_russian = stopwords.words('russian')
# Out:
# [nltk_data] Downloading package stopwords to C:\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
text_transformer = TfidfVectorizer(stop_words=stop_russian)
description = text_transformer.fit_transform(leveled_vacs['description'])

# %%
levels_dict = pd.Series(leveled_vacs['Level'].unique()).to_dict()
levels_dict = {y: x for x, y in levels_dict.items()}
leveled_vacs['Level'] = leveled_vacs['Level'].apply(lambda x:levels_dict[x])

# %%
X_train, X_test, y_train, y_test = train_test_split(description, leveled_vacs['Level'], test_size=0.20, random_state=123)
clf = tree.DecisionTreeClassifier()
level_fit = clf.fit(X_train,y_train)

# %%
pred = level_fit.predict(X_test)
print('Качество модели по метрике F1', f1_score(y_test,pred,average='weighted'))
# Out:
# Качество модели по метрике F1 0.6685033860149067

# %%
not_leveled_vacs = vacs_and_skills[vacs_and_skills['Level'].isnull()].copy()
description_nl = text_transformer.fit_transform(not_leveled_vacs['description'])

# %%
description
# Out:
# <910x22320 sparse matrix of type '<class 'numpy.float64'>'
# 	with 177631 stored elements in Compressed Sparse Row format>

# %%
len(level_fit.predict(description_nl[:, :22320]))
# Out:
# 2412

# %%
levels_dict = {y: x for x, y in levels_dict.items()}

# %%
levels_dict
# Out:
# {0: 'Lead', 1: 'Senior', 2: 'Junior', 3: 'Middle'}

# %%
predicted_level = pd.Series(level_fit.predict(description_nl[:, :22320]))
predicted_level = predicted_level.apply(lambda x:levels_dict[x])
predicted_level = pd.DataFrame(predicted_level)
predicted_level['id'] = vacs_and_skills[vacs_and_skills['Level'].isnull()].reset_index()['id']
predicted_level
# Out:
#            0        id
# 0     Senior  71426958
# 1     Senior  71559745
# 2     Senior  71209351
# 3     Senior  71714632
# 4     Senior  71562226
# ...      ...       ...
# 2407  Senior  71315359
# 2408  Senior  71415345
# 2409  Senior  71145212
# 2410  Senior  71119665
# 2411  Senior  69015080
#
# [2412 rows x 2 columns]

# %%
vacs_and_skills = vacs_and_skills.join(predicted_level.set_index('id'), on='id')

# %%
vacs_and_skills['Level'].fillna(vacs_and_skills[0], inplace=True)
vacs_and_skills.drop(labels = [0], axis = 1, inplace = True)
vacs_and_skills
# Out:
#             id  premium                                               name  \
# 0     71426958     True                    Data Scientist (команда Поиска)
# 1     70994665    False      ML Team Lead (Играющий тренер data scientist)
# 2     71703435    False                           Chief Data Officer (CDO)
# 3     70735115    False                Senior Data Scientist / ML Engineer
# 4     71559745    False                    Data scientist / ML разработчик
# ...        ...      ...                                                ...
# 3317  71415345    False                                      ETL-developer
# 3318  71145212    False  Тайный покупатель (оператор проверки объявлени...
# 3319  71119665    False                           Frontend-разработчик Vue
# 3320  69015080    False                     Менеджер по работе с клиентами
# 3321  70798709    False                    Java Developer (Middle+/Senior)
#
#                                                  skills  \
# 0     [Python, PyTorch, SQL, Machine Learning, Анали...
# 1     [Python, PyTorch, Tensorflow, Deep Learning, K...
# 2     [Python, SQL, Английский язык, Leadership Skil...
# 3     [Docker, Python, SQL, Pandas, Numpy, Scipy, Sc...
# 4     [Python, SQL, A/B тесты, Airflow, Spark, Flask...
# ...                                                 ...
# 3317  [SQL, Python, Java, PostgreSQL, ETL, Clickhous...
# 3318  [Консультирование клиентов по телефону, Коммун...
# 3319  [JavaScript, Vue.js, HTML, CSS, Babel, Webpack...
# 3320  [Телефонные переговоры, Работа с большим объем...
# 3321  [Spring Framework, PostgreSQL, Hibernate ORM, ...
#
#                                             description  has_test  \
# 0     мы ищем data scientist’а с опытом работы в тек...     False
# 1     ооо нейросетевая корпорация экосфера занимаетс...     False
# 2     we are an established b2b events organizing bu...     False
# 3     mindbox — крупнейшая в россии облачная платфор...     False
# 4     компания loymax - лидер на рынке it решений по...     False
# ...                                                 ...       ...
# 3317  ищем коллегу на проект по созданию и развитию ...     False
# 3318  компания training data занимается разметкой да...     False
# 3319  justwork — аутсорс-разработчик систем со сложн...      True
# 3320  idf eurasia специализируется на data science, ...     False
# 3321  сейчас мы расширяем команды и ищем разработчик...     False
#
#       response_letter_required       area      type              published_at  \
# 0                         True     Москва  Открытая 2022-10-27 15:35:01+03:00
# 1                        False     Москва  Открытая 2022-10-28 19:33:00+03:00
# 2                        False     Москва  Открытая 2022-10-28 13:56:31+03:00
# 3                        False     Москва  Открытая 2022-10-28 10:27:43+03:00
# 4                        False     Москва  Открытая 2022-10-28 13:03:53+03:00
# ...                        ...        ...       ...                       ...
# 3317                     False  Волгоград  Открытая 2022-10-21 10:20:15+03:00
# 3318                     False  Волгоград  Открытая 2022-10-14 13:09:02+03:00
# 3319                     False  Волгоград  Открытая 2022-10-13 18:05:51+03:00
# 3320                     False  Волгоград  Открытая 2022-10-12 15:17:42+03:00
# 3321                     False  Волгоград  Открытая 2022-10-05 11:34:12+03:00
#
#       ... accept_temporary  department.id                     department.name  \
# 0     ...            False     hh-1455-ds  HeadHunter::Analytics/Data Science
# 1     ...            False            NaN                                 NaN
# 2     ...            False            NaN                                 NaN
# 3     ...            False            NaN                                 NaN
# 4     ...            False            NaN                                 NaN
# ...   ...              ...            ...                                 ...
# 3317  ...            False            NaN                                 NaN
# 3318  ...             True            NaN                                 NaN
# 3319  ...            False            NaN                                 NaN
# 3320  ...            False            NaN                                 NaN
# 3321  ...            False            NaN                                 NaN
#
#      salary.from salary.to salary.currency salary.gross  \
# 0       350000.0       NaN             RUR         True
# 1       750000.0       NaN             RUR        False
# 2         3000.0    3700.0             EUR         True
# 3       300000.0  450000.0             RUR        False
# 4       120000.0  220000.0             RUR        False
# ...          ...       ...             ...          ...
# 3317         NaN       NaN             NaN          NaN
# 3318         NaN   22500.0             RUR        False
# 3319     90000.0  160000.0             RUR        False
# 3320     45000.0       NaN             RUR         True
# 3321         NaN       NaN             NaN          NaN
#
#                                     snippet.requirement  \
# 0     Опыт реализации и применения моделей машинного...
# 1     Глубокие знания в области Deep Learning/ Machi...
# 2     The successful candidate must have a proven tr...
# 3     DS-stack: docker, python 3.7, sql, pandas, sci...
# 4     Высшее образование в области прикладной матема...
# ...                                                 ...
# 3317  Опыт работы с NoSQL (сlickhouse, cassandra, el...
# 3318  Готовы открыть самозанятость и работать по дог...
# 3319  Ищем фронтменов для текущих и новых проектов. ...
# 3320  Мы обучим всему, что необходимо. Единственное,...
# 3321  Опыт разработки на Java от 3-х лет. Опыт разра...
#
#                                  snippet.responsibility   Level
# 0     Развитие моделей поискового ранжирования и рек...  Senior
# 1     Основной проект компании - разработка унифицир...    Lead
# 2     ...and protecting <highlighttext>data</highlig...    Lead
# 3     Детали. Нейронки, контент-бейзд рекомендации, ...  Senior
# 4     Участие в поддержке текущих, а также развертыв...  Senior
# ...                                                 ...     ...
# 3317  Изучать возможности разных ETL-систем и приним...  Senior
# 3318  Обзвон объявлений по недвижимости в качестве т...  Senior
# 3319                                               None  Senior
# 3320  Вести телефонные переговоры с клиентами с цель...  Senior
# 3321  Инвестиции. Строим уникальный и технологичный ...  Middle
#
# [3328 rows x 28 columns]

# %% [markdown]
# #### Строим модель для прогнозирования зарплаты в вакансиях, где она не указана

# %%
df = vacs_and_skills[vacs_and_skills['salary.from'].notnull()].copy()
df.drop(labels=['type','premium','archived','relations','working_days','published_at',
                'created_at','working_time_modes','working_time_intervals'],axis=1, inplace=True)
df['salary.currency'] = df['salary.currency'].map({'RUR':0,'USD':1,'EUR':2})
df['has_test']=df['has_test'].astype(int)
df['response_letter_required']=df['response_letter_required'].astype(int)
df['accept_temporary']=df['accept_temporary'].astype(int)
df['id']=df['id'].astype(int)
df['description'] = df['description'].fillna('Empty')
df['skills']=df['skills'].str.join(' ,').fillna('Empty')
df = df.dropna(axis=1)

# %%
df
# Out:
#             id                                               name  \
# 0     71426958                    Data Scientist (команда Поиска)
# 1     70994665      ML Team Lead (Играющий тренер data scientist)
# 2     71703435                           Chief Data Officer (CDO)
# 3     70735115                Senior Data Scientist / ML Engineer
# 4     71559745                    Data scientist / ML разработчик
# ...        ...                                                ...
# 3314  71021916                     Старший специалист по продажам
# 3315  69841085        Специалист по работе с клиентами (Мани Мен)
# 3316  71315359  Специалист технической поддержки в Яндекс Верт...
# 3319  71119665                           Frontend-разработчик Vue
# 3320  69015080                     Менеджер по работе с клиентами
#
#                                                  skills  \
# 0     Python ,PyTorch ,SQL ,Machine Learning ,Анализ...
# 1     Python ,PyTorch ,Tensorflow ,Deep Learning ,Keras
# 2     Python ,SQL ,Английский язык ,Leadership Skill...
# 3     Docker ,Python ,SQL ,Pandas ,Numpy ,Scipy ,Sci...
# 4     Python ,SQL ,A/B тесты ,Airflow ,Spark ,Flask ...
# ...                                                 ...
# 3314  Прямые продажи ,Деловое общение ,Активные прод...
# 3315  Грамотная речь ,Работа с базами данных ,Работа...
# 3316  HTTP ,Многозадачность ,API ,Умение расставлять...
# 3319  JavaScript ,Vue.js ,HTML ,CSS ,Babel ,Webpack ...
# 3320  Телефонные переговоры ,Работа с большим объемо...
#
#                                             description  has_test  \
# 0     мы ищем data scientist’а с опытом работы в тек...         0
# 1     ооо нейросетевая корпорация экосфера занимаетс...         0
# 2     we are an established b2b events organizing bu...         0
# 3     mindbox — крупнейшая в россии облачная платфор...         0
# 4     компания loymax - лидер на рынке it решений по...         0
# ...                                                 ...       ...
# 3314  билайн предоставляет услуги как крупнейшим меж...         0
# 3315  id finance специализируется на data science, к...         0
# 3316  cm.expert — первая и ведущая в россии data min...         1
# 3319  justwork — аутсорс-разработчик систем со сложн...         1
# 3320  idf eurasia специализируется на data science, ...         0
#
#       response_letter_required       area            employer  \
# 0                            1     Москва          HeadHunter
# 1                            0     Москва        НСК ЭкоСфера
# 2                            0     Москва  НАО Тринити Ивентс
# 3                            0     Москва             Mindbox
# 4                            0     Москва              Loymax
# ...                        ...        ...                 ...
# 3314                         0  Волгоград              билайн
# 3315                         0  Волгоград         IDF Eurasia
# 3316                         0  Волгоград              Яндекс
# 3319                         0  Волгоград          ДЖАСТ ВОРК
# 3320                         0  Волгоград         IDF Eurasia
#
#               schedule  accept_temporary  salary.from  salary.currency   Level
# 0          Полный день                 0     350000.0                0  Senior
# 1          Полный день                 0     750000.0                0    Lead
# 2     Удаленная работа                 0       3000.0                2    Lead
# 3        Гибкий график                 0     300000.0                0  Senior
# 4          Полный день                 0     120000.0                0  Senior
# ...                ...               ...          ...              ...     ...
# 3314       Полный день                 0      70000.0                0  Senior
# 3315       Полный день                 0      40000.0                0  Senior
# 3316  Удаленная работа                 0      28000.0                0  Senior
# 3319  Удаленная работа                 0      90000.0                0  Senior
# 3320    Сменный график                 0      45000.0                0  Senior
#
# [681 rows x 13 columns]

# %%
#Трансформируем название вакансии в матрицу TF-IDF
text_transformer = TfidfVectorizer()
names = text_transformer.fit_transform(df['name'])

# %%
#Трансформируем навыки в матрицу TF-IDF
skills = text_transformer.fit_transform(df['skills'])

# %%
#Трансформируем название организации-работодателя в матрицу TF-IDF
employer = text_transformer.fit_transform(df['employer'])

# %%
#Трансформируем описание вакансии в матрицу TF-IDF
text_transformer = TfidfVectorizer(stop_words=stop_russian)
description = text_transformer.fit_transform(df['description'])

# %% [markdown]
# #### Сравниваем метрику MAE при расчете по разным данным

# %%
clf = tree.DecisionTreeClassifier()

# %%
X_train, X_test, y_train, y_test = train_test_split(names, df['salary.from'], test_size=0.20, random_state=123)
names_fit = clf.fit(X_train,y_train)
print('Ошибка в предсказании по названию вакансии -', MAE(y_test, names_fit.predict(X_test)))
print('Средняя зарплата -', df['salary.from'].mean())
# Out:
# Ошибка в предсказании по названию вакансии - 47849.94160583941
# Средняя зарплата - 103626.84875183554

# %%
X_train, X_test, y_train, y_test = train_test_split(skills, df['salary.from'], test_size=0.20, random_state=123)
skills_fit = clf.fit(X_train,y_train)
print('Ошибка в предсказании по навыкам -', MAE(y_test, skills_fit.predict(X_test)))
print('Средняя зарплата -', df['salary.from'].mean())
# Out:
# Ошибка в предсказании по навыкам - 50343.54744525548
# Средняя зарплата - 103626.84875183554

# %%
X_train, X_test, y_train, y_test = train_test_split(employer, df['salary.from'], test_size=0.20, random_state=123)
emploer_fit = clf.fit(X_train,y_train)
print('Ошибка в предсказании по работодателю -', MAE(y_test, emploer_fit.predict(X_test)))
print('Средняя зарплата -', df['salary.from'].mean())
# Out:
# Ошибка в предсказании по работодателю - 59406.087591240874
# Средняя зарплата - 103626.84875183554

# %%
X_train, X_test, y_train, y_test = train_test_split(description, df['salary.from'], test_size=0.20, random_state=123)
description_fit = clf.fit(X_train,y_train)
print('Ошибка в предсказании по описанию вакансии -', MAE(y_test, description_fit.predict(X_test)))
print('Средняя зарплата -', df['salary.from'].mean())
# Out:
# Ошибка в предсказании по описанию вакансии - 38153.53284671533
# Средняя зарплата - 103626.84875183554

# %% [markdown]
# #### Строим модель линейной регрессии для анализа по нетекстовым колонкам

# %%
lr_df = df.drop(labels=['id','name','skills','description'], axis=1)
lr_df
# Out:
#       has_test  response_letter_required       area            employer  \
# 0            0                         1     Москва          HeadHunter
# 1            0                         0     Москва        НСК ЭкоСфера
# 2            0                         0     Москва  НАО Тринити Ивентс
# 3            0                         0     Москва             Mindbox
# 4            0                         0     Москва              Loymax
# ...        ...                       ...        ...                 ...
# 3314         0                         0  Волгоград              билайн
# 3315         0                         0  Волгоград         IDF Eurasia
# 3316         1                         0  Волгоград              Яндекс
# 3319         1                         0  Волгоград          ДЖАСТ ВОРК
# 3320         0                         0  Волгоград         IDF Eurasia
#
#               schedule  accept_temporary  salary.from  salary.currency   Level
# 0          Полный день                 0     350000.0                0  Senior
# 1          Полный день                 0     750000.0                0    Lead
# 2     Удаленная работа                 0       3000.0                2    Lead
# 3        Гибкий график                 0     300000.0                0  Senior
# 4          Полный день                 0     120000.0                0  Senior
# ...                ...               ...          ...              ...     ...
# 3314       Полный день                 0      70000.0                0  Senior
# 3315       Полный день                 0      40000.0                0  Senior
# 3316  Удаленная работа                 0      28000.0                0  Senior
# 3319  Удаленная работа                 0      90000.0                0  Senior
# 3320    Сменный график                 0      45000.0                0  Senior
#
# [681 rows x 9 columns]

# %%
levels_dict = {y: x for x, y in levels_dict.items()}
levels_dict
# Out:
# {'Lead': 0, 'Senior': 1, 'Junior': 2, 'Middle': 3}

# %%
emp_dict = pd.Series(lr_df['employer'].unique()).to_dict()
emp_dict = {y: x for x, y in emp_dict.items()}

# %%
reg_dict = {}
for region in regions:
    reg_dict[region['text']] = region['id']

# %%
schedule_dict = pd.Series(lr_df['schedule'].unique()).to_dict()
schedule_dict = {y: x for x, y in schedule_dict.items()}

# %%
lr_df['employer'] = lr_df['employer'].apply(lambda x:emp_dict[x])
lr_df['schedule'] = lr_df['schedule'].apply(lambda x:schedule_dict[x])
lr_df['area'] = lr_df['area'].apply(lambda x:reg_dict[x])
lr_df['Level'] = lr_df['Level'].apply(lambda x:levels_dict[x])
lr_df
# Out:
#       has_test  response_letter_required area  employer  schedule  \
# 0            0                         1    1         0         0
# 1            0                         0    1         1         0
# 2            0                         0    1         2         1
# 3            0                         0    1         3         2
# 4            0                         0    1         4         0
# ...        ...                       ...  ...       ...       ...
# 3314         0                         0   24        89         0
# 3315         0                         0   24       137         0
# 3316         1                         0   24       214         1
# 3319         1                         0   24       267         1
# 3320         0                         0   24       137         3
#
#       accept_temporary  salary.from  salary.currency  Level
# 0                    0     350000.0                0      1
# 1                    0     750000.0                0      0
# 2                    0       3000.0                2      0
# 3                    0     300000.0                0      1
# 4                    0     120000.0                0      1
# ...                ...          ...              ...    ...
# 3314                 0      70000.0                0      1
# 3315                 0      40000.0                0      1
# 3316                 0      28000.0                0      1
# 3319                 0      90000.0                0      1
# 3320                 0      45000.0                0      1
#
# [681 rows x 9 columns]

# %%
from sklearn.linear_model import LinearRegression as lr
X_train, X_test, y_train, y_test = train_test_split(lr_df.drop('salary.from',axis=1),
                                                   lr_df['salary.from'],
                                                   test_size=0.2,
                                                   random_state=123
                                                   )

# %%
clf = lr()
lr_fit = clf.fit(X_train,y_train)
print('Ошибка в предсказании по линейной регрессии -', MAE(lr_fit.predict(X_test),y_test))
print('Средняя зарплата -', df['salary.from'].mean())
# Out:
# Ошибка в предсказании по линейной регрессии - 55172.42606915337
# Средняя зарплата - 103626.84875183554
